# %%
import requests
import numpy as np

# %%
import pandas as pd

# %%
API_KEY = '810bb04d204d43e8b144d6c09bd49db6'
country_code = 'us'
query = 'apple'
endpoint_headline = f'https://newsapi.org/v2/top-headlines?country={country_code}&apiKey={API_KEY}'
endpoint_everything = f'https://newsapi.org/v2/everything?q={query}&apiKey={API_KEY}'
response = requests.get(endpoint_everything)
#response.json()

# %%
df = pd.json_normalize(response.json()['articles'])

# %%
df
# Out:
#            author                                              title  \
# 0   Jake Peterson          The Best Prime Day Deals on Apple Devices
# 1     Amanda Blum  My Three Favorite Tools for Processing Summer ...
# 2   Lawrence Bonk   Apple Watch Series 8 falls to $280 for Prime Day
# 3      Jon Fingas  Apple supplier TSMC delays Arizona chip produc...
# 4       Emma Roth  Apple is taking applications for Vision Pro de...
# ..            ...                                                ...
# 95           None  India to face apple crunch as heavy rain hits ...
# 96  Joe Rossignol  Apple TV+ Shows Now Available to Watch on Air ...
# 97    Cork Gaines                Why Apple is so obsessed with India
# 98  Brad Anderson  Amazon and Apple Just Got Hit With a $218 Mill...
# 99    Juli Clover  Apple Releases New visionOS Beta Ahead of Send...
#
#                                           description  \
# 0   Apple makes some expensive tech, so it makes s...
# 1   Processing fruit every summer can be daunting....
# 2   Apple’s latest and greatest smartwatch, the Se...
# 3   TSMC won't be making chips in Arizona on sched...
# 4   Apple has opened applications for its Vision P...
# ..                                                ...
# 95  India to face apple crunch as heavy rain hits ...
# 96  Air Canada today announced that its in-flight ...
# 97  A growing middle class and demand for high-end...
# 98  Apple and Amazon were fined a combined $218 mi...
# 99  Apple today released a second beta of visionOS...
#
#                                                   url  \
# 0   https://lifehacker.com/the-best-prime-day-deal...
# 1   https://lifehacker.com/my-three-favorite-tools...
# 2   https://www.engadget.com/apple-watch-series-8-...
# 3   https://www.engadget.com/apple-supplier-tsmc-d...
# 4   https://www.theverge.com/2023/7/24/23805883/ap...
# ..                                                ...
# 95  https://consent.google.com/ml?continue=https:/...
# 96  https://www.macrumors.com/2023/08/01/apple-tv-...
# 97  https://www.businessinsider.com/apple-tim-cook...
# 98  https://readwrite.com/amazon-and-apple-just-go...
# 99  https://www.macrumors.com/2023/07/25/apple-rel...
#
#                                            urlToImage           publishedAt  \
# 0   https://i.kinja-img.com/gawker-media/image/upl...  2023-07-11T15:30:00Z
# 1   https://i.kinja-img.com/gawker-media/image/upl...  2023-07-19T14:30:00Z
# 2   https://s.yimg.com/uu/api/res/1.2/V5UrBWtI_v2p...  2023-07-11T10:37:31Z
# 3   https://s.yimg.com/uu/api/res/1.2/f4dWuGYKcmUn...  2023-07-21T15:30:28Z
# 4   https://cdn.vox-cdn.com/thumbor/Y7KYVxd9uuiQWL...  2023-07-24T17:28:51Z
# ..                                                ...                   ...
# 95                                               None  2023-07-24T05:32:00Z
# 96  https://images.macrumors.com/t/75OeY_rBrawC_co...  2023-08-01T14:47:08Z
# 97  https://i.insider.com/64b6aec976558a00189d1e23...  2023-07-18T18:22:12Z
# 98  https://images.readwrite.com/wp-content/upload...  2023-07-19T00:38:37Z
# 99  https://images.macrumors.com/t/SBzHPBLGxpliBkk...  2023-07-25T17:55:36Z
#
#                                               content         source.id  \
# 0   Apple makes some expensive tech, so it makes s...              None
# 1   Processing fruit every summer can be daunting....              None
# 2   Apples latest and greatest smartwatch, the Ser...          engadget
# 3   TSMC won't be making chips in Arizona on sched...          engadget
# 4   Apple is taking applications for Vision Pro de...         the-verge
# ..                                                ...               ...
# 95  We use cookies and data to<ul><li>Deliver and ...       google-news
# 96  Air Canada today announced that its in-flight ...              None
# 97  Apple CEO Tim Cook stands next to the new Appl...  business-insider
# 98  Apple and Amazon were fined a combined $218 mi...              None
# 99  Apple today released a second beta of visionOS...              None
#
#          source.name
# 0     Lifehacker.com
# 1     Lifehacker.com
# 2           Engadget
# 3           Engadget
# 4          The Verge
# ..               ...
# 95       Google News
# 96         MacRumors
# 97  Business Insider
# 98         ReadWrite
# 99         MacRumors
#
# [100 rows x 9 columns]

# %%
df['title']
# Out:
# 0             The Best Prime Day Deals on Apple Devices
# 1     My Three Favorite Tools for Processing Summer ...
# 2      Apple Watch Series 8 falls to $280 for Prime Day
# 3     Apple supplier TSMC delays Arizona chip produc...
# 4     Apple is taking applications for Vision Pro de...
#                             ...
# 95    India to face apple crunch as heavy rain hits ...
# 96    Apple TV+ Shows Now Available to Watch on Air ...
# 97                  Why Apple is so obsessed with India
# 98    Amazon and Apple Just Got Hit With a $218 Mill...
# 99    Apple Releases New visionOS Beta Ahead of Send...
# Name: title, Length: 100, dtype: object

# %%
dfnew=df[['title']]

# %%
dfnew['text'] = df['title']+' '+df['content']+' '+df['description']
# Out:
# /var/folders/nw/mj_fmkh561l2yp1b42p5qf480000gn/T/ipykernel_32504/2893543555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['text'] = df['title']+' '+df['content']+' '+df['description']

# %%
dfnew.head()
# Out:
#                                                title  \
# 0          The Best Prime Day Deals on Apple Devices
# 1  My Three Favorite Tools for Processing Summer ...
# 2   Apple Watch Series 8 falls to $280 for Prime Day
# 3  Apple supplier TSMC delays Arizona chip produc...
# 4  Apple is taking applications for Vision Pro de...
#
#                                                 text
# 0  The Best Prime Day Deals on Apple Devices Appl...
# 1  My Three Favorite Tools for Processing Summer ...
# 2  Apple Watch Series 8 falls to $280 for Prime D...
# 3  Apple supplier TSMC delays Arizona chip produc...
# 4  Apple is taking applications for Vision Pro de...

# %%
dfnew['text'][14]=str(df['title'][14])+str(df['content'][14])
# Out:
# /var/folders/nw/mj_fmkh561l2yp1b42p5qf480000gn/T/ipykernel_32504/907547540.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['text'][14]=str(df['title'][14])+str(df['content'][14])

# %%
dfnew
# Out:
#                                                 title  \
# 0           The Best Prime Day Deals on Apple Devices
# 1   My Three Favorite Tools for Processing Summer ...
# 2    Apple Watch Series 8 falls to $280 for Prime Day
# 3   Apple supplier TSMC delays Arizona chip produc...
# 4   Apple is taking applications for Vision Pro de...
# ..                                                ...
# 95  India to face apple crunch as heavy rain hits ...
# 96  Apple TV+ Shows Now Available to Watch on Air ...
# 97                Why Apple is so obsessed with India
# 98  Amazon and Apple Just Got Hit With a $218 Mill...
# 99  Apple Releases New visionOS Beta Ahead of Send...
#
#                                                  text
# 0   The Best Prime Day Deals on Apple Devices Appl...
# 1   My Three Favorite Tools for Processing Summer ...
# 2   Apple Watch Series 8 falls to $280 for Prime D...
# 3   Apple supplier TSMC delays Arizona chip produc...
# 4   Apple is taking applications for Vision Pro de...
# ..                                                ...
# 95  India to face apple crunch as heavy rain hits ...
# 96  Apple TV+ Shows Now Available to Watch on Air ...
# 97  Why Apple is so obsessed with India Apple CEO ...
# 98  Amazon and Apple Just Got Hit With a $218 Mill...
# 99  Apple Releases New visionOS Beta Ahead of Send...
#
# [100 rows x 2 columns]

# %%
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

sw = set(stopwords.words('english'))

def black_txt(token):
    return  token not in sw and token not in list(string.punctuation) and len(token)>2 

def clean_txt(text):
    clean_text = []
    clean_text2 = []
    text = re.sub("'",'',text) 
    text = re.sub("(\\d|\\W)+"," ", text) 
#     clean = re.compile('<.*?>')
#     text = re.sub(clean,'',text)
    clean_text = [nltk.stem.WordNetLemmatizer().lemmatize(word,pos="v") for word in word_tokenize(text.lower()) if black_txt(word)]
    clean_text2 = [word for word in clean_text if black_txt(word)] 
    return " ".join(clean_text2)

# %%
dfnew['text'] = dfnew['text'].map(str).apply(clean_txt)
# Out:
# /var/folders/nw/mj_fmkh561l2yp1b42p5qf480000gn/T/ipykernel_32504/3547685845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfnew['text'] = dfnew['text'].map(str).apply(clean_txt)

# %%
dfnew
# Out:
#                                                 title  \
# 0           The Best Prime Day Deals on Apple Devices
# 1   My Three Favorite Tools for Processing Summer ...
# 2    Apple Watch Series 8 falls to $280 for Prime Day
# 3   Apple supplier TSMC delays Arizona chip produc...
# 4   Apple is taking applications for Vision Pro de...
# ..                                                ...
# 95  India to face apple crunch as heavy rain hits ...
# 96  Apple TV+ Shows Now Available to Watch on Air ...
# 97                Why Apple is so obsessed with India
# 98  Amazon and Apple Just Got Hit With a $218 Mill...
# 99  Apple Releases New visionOS Beta Ahead of Send...
#
#                                                  text
# 0   best prime day deal apple devices apple make e...
# 1   three favorite tool process summer fruit proce...
# 2   apple watch series fall prime day apples lates...
# 3   apple supplier tsmc delay arizona chip product...
# 4   apple take applications vision pro developer k...
# ..                                                ...
# 95  india face apple crunch heavy rain hit product...
# 96  apple show available watch air canada flight a...
# 97  apple obsess india apple ceo tim cook stand ne...
# 98  amazon apple get hit million fine apple amazon...
# 99  apple release new visionos beta ahead send vis...
#
# [100 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
from sklearn.metrics.pairwise import cosine_similarity 
tfidf_all = tfidf_vectorizer.fit_transform(dfnew['text'])

# %%
def score(title):
    global output
    
    print(title['text'])
    user_tfidf = tfidf_vectorizer.transform(title['text'])
    cos_similarity_tfidf = map(lambda x: cosine_similarity(user_tfidf, x),tfidf_all) 
    output = list(cos_similarity_tfidf)

# %%
def recommend(top, dfnew, scores):
    recommendation = pd.DataFrame(columns = ['title', 'score']) 
    count = 0
    for i in top:
        recommendation.at[count, 'title'] = dfnew['title'][i] 
        recommendation.at[count, 'score'] =  scores[count]
        count += 1
    return recommendation

# %%
def get_recommendation(title,key):
    global output 
    df = pd.DataFrame(columns=[key])
    df[key] = [title]
    score(df)
    top = sorted(range(len(output)), key=lambda i: output[i], reverse=True)[:11] 
    
    list_scores = [output[i][0][0] for i in top]
    rec=recommend(top,dfnew, list_scores)
    
    return rec

# %%
indices = pd.Series(dfnew.index, index=dfnew['title']).drop_duplicates()
indices
# Out:
# title
# The Best Prime Day Deals on Apple Devices                                     0
# My Three Favorite Tools for Processing Summer Fruit                           1
# Apple Watch Series 8 falls to $280 for Prime Day                              2
# Apple supplier TSMC delays Arizona chip production to 2025                    3
# Apple is taking applications for Vision Pro developer kits                    4
#                                                                              ..
# India to face apple crunch as heavy rain hits production - Reuters India     95
# Apple TV+ Shows Now Available to Watch on Air Canada Flights                 96
# Why Apple is so obsessed with India                                          97
# Amazon and Apple Just Got Hit With a $218 Million Fine. Here’s Why           98
# Apple Releases New visionOS Beta Ahead of Sending Out Vision Pro Dev Kits    99
# Length: 100, dtype: int64

# %%
get_recommendation('Welp. Thats it folks','text')
# Out:
# 0    Welp. Thats it folks
# Name: text, dtype: object
#                                                 title     score
# 0     Apple's MacBook Air M1 is back on sale for $750  0.125453
# 1           The Best Prime Day Deals on Apple Devices       0.0
# 2   My Three Favorite Tools for Processing Summer ...       0.0
# 3    Apple Watch Series 8 falls to $280 for Prime Day       0.0
# 4   Apple supplier TSMC delays Arizona chip produc...       0.0
# 5   Apple is taking applications for Vision Pro de...       0.0
# 6   A new Samba de Amigo game is coming to Apple A...       0.0
# 7   Russia bans state officials from using Apple d...       0.0
# 8   95 Best Prime Day Deals Still Going Strong (20...       0.0
# 9   Author says the Apple TV+ 'Tetris' movie rippe...       0.0
# 10                       How to use Safari Tab Groups       0.0

# %%
get_recommendation('update features','text')
# Out:
# 0    update features
# Name: text, dtype: object
#                                                 title     score
# 0           Apple Releases watchOS 9.6 With Bug Fixes  0.369491
# 1   iOS 16.5.1 (a): Why Apple Removed Access to th...  0.232607
# 2                   Apple Releases macOS Ventura 13.5  0.149663
# 3   Ridiculous Fishing is back, and it is still ve...   0.14428
# 4   iPadOS 17 preview: A smoother multitasking exp...  0.141439
# 5                            Apple Releases tvOS 16.6  0.118181
# 6   Apple iOS, Google Android Patch Zero-Days in J...  0.097863
# 7         How to install the macOS Sonoma public beta   0.08448
# 8   WhatsApp makes it easier to send messages to u...  0.078207
# 9   Apple Gearing Up for Launch of Vision Pro Deve...   0.07753
# 10          The Best Prime Day Deals on Apple Devices       0.0

# %%
get_recommendation('Wall street','text')
# Out:
# 0    Wall street
# Name: text, dtype: object
#                                                 title     score
# 0   Apple profit tops Wall Street targets, weaker ...  0.427058
# 1           The Best Prime Day Deals on Apple Devices       0.0
# 2   My Three Favorite Tools for Processing Summer ...       0.0
# 3    Apple Watch Series 8 falls to $280 for Prime Day       0.0
# 4   Apple supplier TSMC delays Arizona chip produc...       0.0
# 5   Apple is taking applications for Vision Pro de...       0.0
# 6   A new Samba de Amigo game is coming to Apple A...       0.0
# 7   Russia bans state officials from using Apple d...       0.0
# 8   95 Best Prime Day Deals Still Going Strong (20...       0.0
# 9   Author says the Apple TV+ 'Tetris' movie rippe...       0.0
# 10                       How to use Safari Tab Groups       0.0
